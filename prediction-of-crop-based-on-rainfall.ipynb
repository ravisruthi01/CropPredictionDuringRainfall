# %%
import numpy as np 
import pandas as pd 
import os
import matplotlib.pyplot as plot
print(os.listdir("../input"))
# Out:
# ['rainfall-in-india', 'crop-production-statistics-from-1997-in-india']

# %%
datarain= pd.read_csv("../input/rainfall-in-india/rainfall in india 1901-2015.csv")

# %%
print(datarain.head())
# Out:
#                  SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# 0  ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8  517.5
# 1  ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2  ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3  ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4  ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5  628.7
#
#      JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  Mar-May  \
# 0  365.1  481.1  332.6  388.5  558.2   33.6  3373.2    136.3    560.3
# 1  228.9  753.7  666.2  197.2  359.0  160.5  3520.7    159.8    458.3
# 2  728.4  326.7  339.0  181.2  284.4  225.0  2957.4    156.7    236.1
# 3  502.0  160.1  820.4  222.2  308.7   40.1  3079.6     24.1    506.9
# 4  368.7  330.5  297.0  260.7   25.4  344.7  2566.7      1.3    309.7
#
#    Jun-Sep  Oct-Dec
# 0   1696.3    980.3
# 1   2185.9    716.7
# 2   1874.0    690.6
# ...

# %%
print(datarain.columns)
# Out:
# Index(['SUBDIVISION', 'YEAR', 'JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL',
#        'AUG', 'SEP', 'OCT', 'NOV', 'DEC', 'ANNUAL', 'Jan-Feb', 'Mar-May',
#        'Jun-Sep', 'Oct-Dec'],
#       dtype='object')

# %%
set(datarain['SUBDIVISION'])
# Out:
# {'ANDAMAN & NICOBAR ISLANDS',
#  'ARUNACHAL PRADESH',
#  'ASSAM & MEGHALAYA',
#  'BIHAR',
#  'CHHATTISGARH',
#  'COASTAL ANDHRA PRADESH',
#  'COASTAL KARNATAKA',
#  'EAST MADHYA PRADESH',
#  'EAST RAJASTHAN',
#  'EAST UTTAR PRADESH',
#  'GANGETIC WEST BENGAL',
#  'GUJARAT REGION',
#  'HARYANA DELHI & CHANDIGARH',
#  'HIMACHAL PRADESH',
#  'JAMMU & KASHMIR',
#  'JHARKHAND',
#  'KERALA',
#  'KONKAN & GOA',
#  'LAKSHADWEEP',
#  'MADHYA MAHARASHTRA',
#  'MATATHWADA',
#  'NAGA MANI MIZO TRIPURA',
#  'NORTH INTERIOR KARNATAKA',
#  'ORISSA',
#  'PUNJAB',
#  'RAYALSEEMA',
#  'SAURASHTRA & KUTCH',
#  'SOUTH INTERIOR KARNATAKA',
#  'SUB HIMALAYAN WEST BENGAL & SIKKIM',
#  'TAMIL NADU',
#  'TELANGANA',
#  'UTTARAKHAND',
#  'VIDARBHA',
#  'WEST MADHYA PRADESH',
#  'WEST RAJASTHAN',
#  'WEST UTTAR PRADESH'}

# %%
rain= datarain[(datarain['SUBDIVISION']=='BIHAR') | (datarain['SUBDIVISION']=='KERALA') | (datarain['SUBDIVISION']=='ARUNACHAL PRADESH')|(datarain['SUBDIVISION']=='TAMIL NADU')|(datarain['SUBDIVISION']=='JAMMU & KASHMIR')|(datarain['SUBDIVISION']=='UTTARAKHAND')|(datarain['SUBDIVISION']=='ORISSA')|(datarain['SUBDIVISION']=='HIMACHAL PRADESH')|(datarain['SUBDIVISION']=='PUNJAB')|(datarain['SUBDIVISION']=='CHHATTISGARH')|(datarain['SUBDIVISION']=='ANDAMAN & NICOBAR ISLANDS')|(datarain['SUBDIVISION']=='JHARKHAND')]

# %%
print(set(rain['SUBDIVISION']))
print(rain.head())
# Out:
# {'UTTARAKHAND', 'PUNJAB', 'JHARKHAND', 'TAMIL NADU', 'CHHATTISGARH', 'KERALA', 'JAMMU & KASHMIR', 'HIMACHAL PRADESH', 'BIHAR', 'ORISSA', 'ANDAMAN & NICOBAR ISLANDS', 'ARUNACHAL PRADESH'}
#                  SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# 0  ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8  517.5
# 1  ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2  ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3  ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4  ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5  628.7
#
#      JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  Mar-May  \
# 0  365.1  481.1  332.6  388.5  558.2   33.6  3373.2    136.3    560.3
# 1  228.9  753.7  666.2  197.2  359.0  160.5  3520.7    159.8    458.3
# 2  728.4  326.7  339.0  181.2  284.4  225.0  2957.4    156.7    236.1
# ...

# %%
rain = rain[['SUBDIVISION','YEAR','ANNUAL']]
print(rain.head())
print(rain.describe())
# Out:
#                  SUBDIVISION  YEAR  ANNUAL
# 0  ANDAMAN & NICOBAR ISLANDS  1901  3373.2
# 1  ANDAMAN & NICOBAR ISLANDS  1902  3520.7
# 2  ANDAMAN & NICOBAR ISLANDS  1903  2957.4
# 3  ANDAMAN & NICOBAR ISLANDS  1904  3079.6
# 4  ANDAMAN & NICOBAR ISLANDS  1905  2566.7
#               YEAR       ANNUAL
# count  1357.000000  1344.000000
# mean   1958.633751  1626.442932
# std      33.029385   911.230640
# min    1901.000000   274.700000
# 25%    1930.000000  1066.800000
# 50%    1959.000000  1339.500000
# 75%    1987.000000  1795.025000
# max    2015.000000  6331.100000

# %%
datarain['YEAR'].head()
# Out:
# 0    1901
# 1    1902
# 2    1903
# 3    1904
# 4    1905
# Name: YEAR, dtype: int64

# %%
rain = rain[rain['YEAR']>1991]

# %%
rain.columns
# Out:
# Index(['SUBDIVISION', 'YEAR', 'ANNUAL'], dtype='object')

# %%
 rain.columns= ['State','Year','Rainfall']

# %%
print(rain)
# Out:
#                           State  Year  Rainfall
# 86    ANDAMAN & NICOBAR ISLANDS  1992    2098.7
# 87    ANDAMAN & NICOBAR ISLANDS  1993    2237.4
# 88    ANDAMAN & NICOBAR ISLANDS  1994    3262.8
# 89    ANDAMAN & NICOBAR ISLANDS  1995    3115.4
# 90    ANDAMAN & NICOBAR ISLANDS  1996    2996.9
# ...                         ...   ...       ...
# 3997                     KERALA  2011    3035.1
# 3998                     KERALA  2012    2151.1
# 3999                     KERALA  2013    3255.4
# 4000                     KERALA  2014    3046.4
# 4001                     KERALA  2015    2600.6
#
# [288 rows x 3 columns]

# %%
print(set(rain['State']))
# Out:
# {'UTTARAKHAND', 'PUNJAB', 'JHARKHAND', 'TAMIL NADU', 'CHHATTISGARH', 'KERALA', 'JAMMU & KASHMIR', 'HIMACHAL PRADESH', 'BIHAR', 'ORISSA', 'ANDAMAN & NICOBAR ISLANDS', 'ARUNACHAL PRADESH'}

# %%
datacrop = pd.read_csv("../input/crop-production-statistics-from-1997-in-india/apy.csv")

# %%
print(datacrop.head())
# Out:
#                     State_Name District_Name  Crop_Year       Season  \
# 0  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
#
#                   Crop    Area  Production
# 0             Arecanut  1254.0      2000.0
# 1  Other Kharif pulses     2.0         1.0
# 2                 Rice   102.0       321.0
# 3               Banana   176.0       641.0
# 4            Cashewnut   720.0       165.0

# %%
print(set(datacrop['State_Name']))
# Out:
# {'Dadra and Nagar Haveli', 'Madhya Pradesh', 'Jharkhand', 'Kerala', 'Karnataka', 'Odisha', 'Chhattisgarh', 'Nagaland', 'Telangana ', 'Andhra Pradesh', 'Maharashtra', 'Uttar Pradesh', 'Jammu and Kashmir ', 'Goa', 'Manipur', 'Tripura', 'Himachal Pradesh', 'Haryana', 'Puducherry', 'Andaman and Nicobar Islands', 'Mizoram', 'West Bengal', 'Assam', 'Bihar', 'Chandigarh', 'Punjab', 'Tamil Nadu', 'Arunachal Pradesh', 'Uttarakhand', 'Gujarat', 'Rajasthan', 'Sikkim', 'Meghalaya'}

# %%
set(datacrop['State_Name'])
# Out:
# {'Andaman and Nicobar Islands',
#  'Andhra Pradesh',
#  'Arunachal Pradesh',
#  'Assam',
#  'Bihar',
#  'Chandigarh',
#  'Chhattisgarh',
#  'Dadra and Nagar Haveli',
#  'Goa',
#  'Gujarat',
#  'Haryana',
#  'Himachal Pradesh',
#  'Jammu and Kashmir ',
#  'Jharkhand',
#  'Karnataka',
#  'Kerala',
#  'Madhya Pradesh',
#  'Maharashtra',
#  'Manipur',
#  'Meghalaya',
#  'Mizoram',
#  'Nagaland',
#  'Odisha',
#  'Puducherry',
#  'Punjab',
#  'Rajasthan',
#  'Sikkim',
#  'Tamil Nadu',
#  'Telangana ',
#  'Tripura',
#  'Uttar Pradesh',
#  'Uttarakhand',
#  'West Bengal'}

# %%
crop= datacrop[(datacrop['State_Name']=='Bihar') | (datacrop['State_Name']=='Kerala') | (datacrop['State_Name']=='Arunachal Pradesh ')|(datacrop['State_Name']=='Tamil Nadu')|(datacrop['State_Name']=='Jammu and Kashmir')|(datacrop['State_Name']=='Uttarakhand')|(datacrop['State_Name']=='Odisha')|(datacrop['State_Name']=='Himachal Pradesh')|(datacrop['State_Name']=='Punjab')|(datacrop['State_Name']=='Chhattisgarh')|(datacrop['State_Name']=='Andaman and Nicobar Islands')|(datacrop['State_Name']== 'Jharkhand')]

# %%
print(datacrop.head())
# Out:
#                     State_Name District_Name  Crop_Year       Season  \
# 0  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
#
#                   Crop    Area  Production
# 0             Arecanut  1254.0      2000.0
# 1  Other Kharif pulses     2.0         1.0
# 2                 Rice   102.0       321.0
# 3               Banana   176.0       641.0
# 4            Cashewnut   720.0       165.0

# %%
print(set(crop['State_Name']))
print(crop.head())
# Out:
# {'Bihar', 'Punjab', 'Tamil Nadu', 'Jharkhand', 'Kerala', 'Andaman and Nicobar Islands', 'Uttarakhand', 'Odisha', 'Chhattisgarh', 'Himachal Pradesh'}
#                     State_Name District_Name  Crop_Year       Season  \
# 0  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
#
#                   Crop    Area  Production
# 0             Arecanut  1254.0      2000.0
# 1  Other Kharif pulses     2.0         1.0
# 2                 Rice   102.0       321.0
# 3               Banana   176.0       641.0
# 4            Cashewnut   720.0       165.0

# %%
crop_processed_data = pd.DataFrame(columns = ['State','Year','Crop','Area','Production'])
print(crop_processed_data)
# Out:
# Empty DataFrame
# Columns: [State, Year, Crop, Area, Production]
# Index: []

# %%
datacrop = datacrop.drop('Season',axis = 1)

# %%
datacrop = datacrop.drop('District_Name',axis = 1)

# %%
crop=crop.drop(['District_Name', 'Season'], axis=1)

# %%
datacrop.head()
# Out:
#                     State_Name  Crop_Year                 Crop    Area  \
# 0  Andaman and Nicobar Islands       2000             Arecanut  1254.0
# 1  Andaman and Nicobar Islands       2000  Other Kharif pulses     2.0
# 2  Andaman and Nicobar Islands       2000                 Rice   102.0
# 3  Andaman and Nicobar Islands       2000               Banana   176.0
# 4  Andaman and Nicobar Islands       2000            Cashewnut   720.0
#
#    Production
# 0      2000.0
# 1         1.0
# 2       321.0
# 3       641.0
# 4       165.0

# %%
crop_processed_data
# Out:
# Empty DataFrame
# Columns: [State, Year, Crop, Area, Production]
# Index: []

# %%
datacrop
# Out:
#                          State_Name  Crop_Year                 Crop      Area  \
# 0       Andaman and Nicobar Islands       2000             Arecanut    1254.0
# 1       Andaman and Nicobar Islands       2000  Other Kharif pulses       2.0
# 2       Andaman and Nicobar Islands       2000                 Rice     102.0
# 3       Andaman and Nicobar Islands       2000               Banana     176.0
# 4       Andaman and Nicobar Islands       2000            Cashewnut     720.0
# ...                             ...        ...                  ...       ...
# 246086                  West Bengal       2014                 Rice     306.0
# 246087                  West Bengal       2014              Sesamum     627.0
# 246088                  West Bengal       2014            Sugarcane     324.0
# 246089                  West Bengal       2014                 Rice  279151.0
# 246090                  West Bengal       2014              Sesamum     175.0
#
#         Production
# ...

# %%
print(set(crop['State_Name']))
print(set(rain['State']))
# Out:
# {'Bihar', 'Punjab', 'Tamil Nadu', 'Jharkhand', 'Kerala', 'Andaman and Nicobar Islands', 'Uttarakhand', 'Odisha', 'Chhattisgarh', 'Himachal Pradesh'}
# {'UTTARAKHAND', 'PUNJAB', 'JHARKHAND', 'TAMIL NADU', 'CHHATTISGARH', 'KERALA', 'JAMMU & KASHMIR', 'HIMACHAL PRADESH', 'BIHAR', 'ORISSA', 'ANDAMAN & NICOBAR ISLANDS', 'ARUNACHAL PRADESH'}

# %%
crop = crop.replace('Jammu and Kashmir ','Jammu and Kashmir')
rain = rain.replace('UTTARAKHAND','Uttarakhand')
rain = rain.replace('ORISSA','Odisha')
rain = rain.replace('HIMACHAL PRADESH','Himachal Pradesh')
rain = rain.replace('JHARKHAND','Jharkhand')
rain = rain.replace('ARUNACHAL PRADESH','Arunachal Pradesh')
rain = rain.replace('TAMIL NADU','Tamil Nadu')
rain = rain.replace('CHHATTISGARH','Chhattisgarh')
rain = rain.replace('JAMMU & KASHMIR','Jammu and Kashmir')
rain = rain.replace('ANDAMAN & NICOBAR ISLANDS','Andaman and Nicobar Islands')
rain = rain.replace('BIHAR','Bihar')
rain = rain.replace('PUNJAB','Punjab')
rain = rain.replace('KERALA','Kerala')

# %%
Rainfall_list = [0]*73009
crop['Rainfall'] = Rainfall_list

# %%
print(crop.head())
print(rain.head())
# Out:
#                     State_Name  Crop_Year                 Crop    Area  \
# 0  Andaman and Nicobar Islands       2000             Arecanut  1254.0
# 1  Andaman and Nicobar Islands       2000  Other Kharif pulses     2.0
# 2  Andaman and Nicobar Islands       2000                 Rice   102.0
# 3  Andaman and Nicobar Islands       2000               Banana   176.0
# 4  Andaman and Nicobar Islands       2000            Cashewnut   720.0
#
#    Production  Rainfall
# 0      2000.0         0
# 1         1.0         0
# 2       321.0         0
# 3       641.0         0
# 4       165.0         0
#                           State  Year  Rainfall
# 86  Andaman and Nicobar Islands  1992    2098.7
# 87  Andaman and Nicobar Islands  1993    2237.4
# 88  Andaman and Nicobar Islands  1994    3262.8
# 89  Andaman and Nicobar Islands  1995    3115.4
# 90  Andaman and Nicobar Islands  1996    2996.9

# %%
states_set  = set(crop['State_Name'])
year_set = set(crop['Crop_Year'])
print(states_set)
print(year_set )
# Out:
# {'Bihar', 'Punjab', 'Tamil Nadu', 'Jharkhand', 'Kerala', 'Andaman and Nicobar Islands', 'Uttarakhand', 'Odisha', 'Chhattisgarh', 'Himachal Pradesh'}
# {1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015}

# %%
rain
# Out:
#                             State  Year  Rainfall
# 86    Andaman and Nicobar Islands  1992    2098.7
# 87    Andaman and Nicobar Islands  1993    2237.4
# 88    Andaman and Nicobar Islands  1994    3262.8
# 89    Andaman and Nicobar Islands  1995    3115.4
# 90    Andaman and Nicobar Islands  1996    2996.9
# ...                           ...   ...       ...
# 3997                       Kerala  2011    3035.1
# 3998                       Kerala  2012    2151.1
# 3999                       Kerala  2013    3255.4
# 4000                       Kerala  2014    3046.4
# 4001                       Kerala  2015    2600.6
#
# [288 rows x 3 columns]

# %%
for state in states_set:
        for year in year_set:
            if(year in list(crop[crop['State_Name']==state]['Crop_Year'])):
                crop.loc[(crop['State_Name']==state) & \
                (crop['Crop_Year']==year),'Rainfall']= \
                list(rain[(rain['State']==state) & \
                                   (rain['Year']==year)]['Rainfall'])[0]

# %%
crop
# Out:
#                          State_Name  Crop_Year                 Crop     Area  \
# 0       Andaman and Nicobar Islands       2000             Arecanut   1254.0
# 1       Andaman and Nicobar Islands       2000  Other Kharif pulses      2.0
# 2       Andaman and Nicobar Islands       2000                 Rice    102.0
# 3       Andaman and Nicobar Islands       2000               Banana    176.0
# 4       Andaman and Nicobar Islands       2000            Cashewnut    720.0
# ...                             ...        ...                  ...      ...
# 236473                  Uttarakhand       2014                Onion     26.0
# 236474                  Uttarakhand       2014         Pulses total   5346.0
# 236475                  Uttarakhand       2014                 Rice   9919.0
# 236476                  Uttarakhand       2014            Sunflower      3.0
# 236477                  Uttarakhand       2014      Total foodgrain  35417.0
#
#         Production  Rainfall
# ...

# %%
crop_data = crop.dropna()
crop_data = crop_data[crop_data.Production !=0.0]
print(crop_data.head())
print(set(crop_data['Crop']))
# Out:
#                     State_Name  Crop_Year                 Crop    Area  \
# 0  Andaman and Nicobar Islands       2000             Arecanut  1254.0
# 1  Andaman and Nicobar Islands       2000  Other Kharif pulses     2.0
# 2  Andaman and Nicobar Islands       2000                 Rice   102.0
# 3  Andaman and Nicobar Islands       2000               Banana   176.0
# 4  Andaman and Nicobar Islands       2000            Cashewnut   720.0
#
#    Production  Rainfall
# 0      2000.0    2763.2
# 1         1.0    2763.2
# 2       321.0    2763.2
# 3       641.0    2763.2
# 4       165.0    2763.2
# ...

# %%
crop_data.describe()
# Out:
#           Crop_Year           Area    Production      Rainfall
# count  70822.000000   70822.000000  7.082200e+04  70822.000000
# mean    2005.608667    8659.874060  1.582138e+06   1264.562362
# std        4.964051   30949.931959  2.979232e+07    512.437943
# min     1997.000000       0.200000  1.000000e-02    274.700000
# 25%     2002.000000      68.000000  6.200000e+01   1032.400000
# 50%     2005.000000     487.000000  5.210000e+02   1219.600000
# 75%     2010.000000    2954.750000  4.318000e+03   1405.900000
# max     2015.000000  687000.000000  1.250800e+09   3489.600000

# %%
crop_data = crop_data.drop('Crop_Year',axis = 1)
crop_data = crop_data.sort_values(by='Crop')
crop_data = crop_data.reset_index(drop=True)
print(crop_data.head())
# Out:
#                     State_Name      Crop      Area  Production  Rainfall
# 0  Andaman and Nicobar Islands  Arecanut   1254.00     2000.00    2763.2
# 1                       Kerala  Arecanut  10692.00    15285.00    2412.6
# 2                   Tamil Nadu  Arecanut      1.00        1.00     741.9
# 3                       Kerala  Arecanut   4943.83     4639.87    3035.1
# 4                       Kerala  Arecanut   4754.00     4052.00    2151.1

# %%
for index,row in crop_data.iterrows():
    crop_data.loc[index,'Production'] = row['Production']/row['Area']
crop_data.head()
# Out:
#                     State_Name      Crop      Area    Production  Rainfall
# 0  Andaman and Nicobar Islands  Arecanut   1254.00  1.014232e-06    2763.2
# 1                       Kerala  Arecanut  10692.00  1.250514e-08    2412.6
# 2                   Tamil Nadu  Arecanut      1.00  1.000000e+00     741.9
# 3                       Kerala  Arecanut   4943.83  3.839859e-08    3035.1
# 4                       Kerala  Arecanut   4754.00  3.771307e-08    2151.1

# %%
crop_data
# Out:
#                         State_Name            Crop      Area    Production  \
# 0      Andaman and Nicobar Islands        Arecanut   1254.00  1.014232e-06
# 1                           Kerala        Arecanut  10692.00  1.250514e-08
# 2                       Tamil Nadu        Arecanut      1.00  1.000000e+00
# 3                           Kerala        Arecanut   4943.83  3.839859e-08
# 4                           Kerala        Arecanut   4754.00  3.771307e-08
# ...                            ...             ...       ...           ...
# 70817                  Uttarakhand  other oilseeds     40.00  5.000000e-01
# 70818                  Uttarakhand  other oilseeds     42.00  4.285714e-01
# 70819                  Uttarakhand  other oilseeds     21.00  6.190476e-01
# 70820                  Uttarakhand  other oilseeds      5.00  6.000000e-01
# 70821                  Uttarakhand  other oilseeds      1.00  1.000000e+00
#
#        Rainfall
# 0        2763.2
# 1        2412.6
# ...

# %%
set(crop['Crop'])
# Out:
# {'Apple',
#  'Arecanut',
#  'Arhar/Tur',
#  'Ash Gourd',
#  'Bajra',
#  'Banana',
#  'Barley',
#  'Beans & Mutter(Vegetable)',
#  'Beet Root',
#  'Ber',
#  'Bhindi',
#  'Bitter Gourd',
#  'Black pepper',
#  'Blackgram',
#  'Bottle Gourd',
#  'Brinjal',
#  'Cabbage',
#  'Cardamom',
#  'Carrot',
#  'Cashewnut',
#  'Cashewnut Raw',
#  'Castor seed',
#  'Cauliflower',
#  'Citrus Fruit',
#  'Coconut ',
#  'Coffee',
#  'Coriander',
#  'Cotton(lint)',
#  'Cowpea(Lobia)',
#  'Cucumber',
#  'Drum Stick',
#  'Dry chillies',
#  'Dry ginger',
#  'Garlic',
#  'Ginger',
#  'Gram',
#  'Grapes',
#  'Groundnut',
#  'Guar seed',
#  'Horse-gram',
#  'Jack Fruit',
#  'Jowar',
#  'Jute',
#  'Khesari',
#  'Korra',
#  'Lab-Lab',
#  'Lentil',
#  'Linseed',
#  'Litchi',
#  'Maize',
#  'Mango',
#  'Masoor',
#  'Mesta',
#  'Moong(Green Gram)',
#  'Moth',
#  'Niger seed',
#  'Onion',
#  'Orange',
#  'Other  Rabi pulses',
#  'Other Cereals & Millets',
#  'Other Citrus Fruit',
#  'Other Fresh Fruits',
# ...

# %%
print(len(wheat_data['Production']))
# Out:
# 2246

# %%
wheat_data = crop_data[crop_data['Crop']=='Wheat']
print(len(wheat_data))
print(wheat_data.head())
print(wheat_data[wheat_data['Production']==3.0])
# Out:
# 2246
#         State_Name   Crop      Area  Production  Rainfall
# 68382        Bihar  Wheat   57876.0    1.758691    1303.7
# 68383        Bihar  Wheat   27209.0    1.864640     889.3
# 68384       Punjab  Wheat  395000.0    4.681013     717.1
# 68385       Punjab  Wheat   85000.0    4.929412     361.2
# 68386  Uttarakhand  Wheat   12895.0    1.672741    1178.9
#       State_Name   Crop  Area  Production  Rainfall
# 69713     Kerala  Wheat   1.0         3.0    3046.4

# %%
plot.scatter(wheat_data['Production'], wheat_data['Rainfall'])

# %%
crop_data['Crop'].head()
# Out:
# 0    Arecanut
# 1    Arecanut
# 2    Arecanut
# 3    Arecanut
# 4    Arecanut
# Name: Crop, dtype: object

# %%
sunflower_data = crop_data[crop_data['Crop']=='Sunflower']

# %%
plot.scatter(sunflower_data['Production'], sunflower_data['Rainfall'])
